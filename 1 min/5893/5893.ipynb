# %%
# %reset
import numpy as np
import pandas as pd
import pickle
from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import  plot_series
from sktime.performance_metrics.forecasting import MeanAbsolutePercentageError

# %%
#Ouvre le fichier CSV du capteur dont les données sont issues
df = pd.read_csv("human_activity_raw_sensor_data_int5893.csv", sep=',', header=0, names=["value_id", "sensor_id", "timestamp", "value"])

#Transtypage des colonnes
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S')
df['value'] = df['value'].astype('int64')

#Selection de la plage de dates à extraire du dataset
df = df[(df['timestamp'] > '2020-03-20') & (df['timestamp'] <= '2020-04-01')]
filtered_df = df.query('value>0.4 or value==0')
filtered_df = filtered_df.set_index('timestamp').asfreq('1min')
filtered_df.fillna(method='ffill', inplace=True)

#Suppression des colonnes inutiles pour l'apprentissage
filtered_df = filtered_df.drop(columns=["sensor_id","value_id"])

# %%
# Slipt test/train des données
y_train, y_test = temporal_train_test_split(filtered_df, test_size=1/3)
plot_series(y_train, y_test, labels=["y_train", "y_test",]);

# %%
fh = ForecastingHorizon(y_test.index, is_relative=False)
forecaster = NaiveForecaster(strategy="last", sp=24*12*7)
print(y_train)

forecaster.fit(y_train)

y_pred = forecaster.predict(fh)
print(y_pred[:10])
#y_pred.fillna(method='ffill', inplace=True)
#y_pred["value"] = y_pred.astype('int64')

# step 3: specifying the evaluation metric
mape = MeanAbsolutePercentageError(symmetric=False)

# step 4: computing the forecast performance
print(mape(y_test, y_pred))
plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"]);
# Out:
#                      value
# 2020-03-20 00:01:00    0.0
# 2020-03-20 00:02:00    0.0
# 2020-03-20 00:03:00    0.0
# 2020-03-20 00:04:00    0.0
# 2020-03-20 00:05:00    0.0
# ...                    ...
# 2020-03-27 23:56:00    0.0
# 2020-03-27 23:57:00    0.0
# 2020-03-27 23:58:00    0.0
# 2020-03-27 23:59:00    0.0
# 2020-03-28 00:00:00    0.0
#
# [11520 rows x 1 columns]
# C:\Users\patrick.olislaegers\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\forecasting\base\_fh.py:533: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   if not hasattr(cutoff, "freqstr") or cutoff.freqstr is None:
# C:\Users\patrick.olislaegers\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\forecasting\base\_fh.py:543: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   assert cutoff.freqstr == index.freqstr
# C:\Users\patrick.olislaegers\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\utils\datetime.py:77: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   if hasattr(x, "freqstr"):
# C:\Users\patrick.olislaegers\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\utils\datetime.py:78: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   if x.freqstr is None:
# C:\Users\patrick.olislaegers\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\utils\datetime.py:80: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   elif "-" in x.freqstr:
# C:\Users\patrick.olislaegers\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\utils\datetime.py:83: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   return x.freqstr
# C:\Users\patrick.olislaegers\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\utils\datetime.py:105: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   if not hasattr(x, "freq") or x.freq is None:
# C:\Users\patrick.olislaegers\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\utils\datetime.py:107: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   by *= x.freq
#                      value
# 2020-03-28 00:01:00    0.0
# 2020-03-28 00:02:00    0.0
# 2020-03-28 00:03:00    0.0
# 2020-03-28 00:04:00    0.0
# 2020-03-28 00:05:00    0.0
# 2020-03-28 00:06:00    0.0
# 2020-03-28 00:07:00    0.0
# 2020-03-28 00:08:00    0.0
# 2020-03-28 00:09:00    0.0
# 2020-03-28 00:10:00    0.0
# 90697492495655.83

# %%
y_pred.query('value>0.0')
# Out:
#                      value
# 2020-03-29 16:01:00    0.0
# 2020-03-29 16:02:00    0.0
# 2020-03-29 16:03:00    0.0
# 2020-03-29 16:04:00    0.0
# 2020-03-29 16:05:00    0.0
# ...                    ...
# 2020-04-08 23:56:00    0.0
# 2020-04-08 23:57:00    0.0
# 2020-04-08 23:58:00    0.0
# 2020-04-08 23:59:00    0.0
# 2020-04-09 00:00:00    0.0
#
# [14880 rows x 1 columns]

# %%
#Sauvegarde du modèle avec Pickle
filename = 'model_5896_bed_pressure.pkl'
pickle.dump(forecaster, open(filename, 'wb'))

# %%
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.compose import EnsembleForecaster
from sktime.forecasting.tbats import TBATS
from sktime.forecasting.arima import AutoARIMA

ensemble = EnsembleForecaster(forecasters = [("tbats", TBATS()),
                                             ("autoarima", AutoARIMA())],                         
                              aggfunc = "min")
ensemble.fit(y_train)
print(ensemble.forecasters_)

# %%
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.arima import AutoARIMA

from sktime.utils.plotting import plot_series


forecaster = AutoARIMA(sp=3)
forecaster.fit(y_train)
y_pred = forecaster.predict(fh)

plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\docstring.py in __missing__(self, key)
#      60         try:
# ---> 61             cls, = [cls for cls in _recursive_subclasses(Artist)
#      62                     if cls.__name__ == name]
#
# ValueError: too many values to unpack (expected 1)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_16296/1025225686.py in <module>
#       1 from sktime.forecasting.model_selection import temporal_train_test_split
#       2 from sktime.forecasting.base import ForecastingHorizon
# ----> 3 from sktime.forecasting.arima import AutoARIMA
#       4
#       5 from sktime.utils.plotting import plot_series
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\forecasting\arima.py in <module>
#      10 from sktime.utils.validation._dependencies import _check_soft_dependencies
#      11
# ---> 12 _check_soft_dependencies("pmdarima")
#      13
#      14
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sktime\utils\validation\_dependencies.py in _check_soft_dependencies(*packages)
#      21     for package in packages:
#      22         try:
# ---> 23             import_module(package)
#      24         except ModuleNotFoundError as e:
#      25             msg = (
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pmdarima\__init__.py in <module>
#      50
#      51     # Stuff we want at top-level
# ---> 52     from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53     from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54         tsdisplay
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pmdarima\arima\__init__.py in <module>
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
#       4
# ----> 5 from .approx import *
#       6 from .arima import *
#       7 from .auto import *
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pmdarima\arima\approx.py in <module>
#       8
#       9 from ..utils.array import c, check_endog
# ---> 10 from ..utils import get_callable
#      11 from ..compat.numpy import DTYPE
#      12
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pmdarima\utils\__init__.py in <module>
#       5 from .array import *
#       6 from .metaestimators import *
# ----> 7 from .visualization import *
#       8 from .wrapped import *
#       9
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pmdarima\utils\visualization.py in <module>
#      22     # If it's a Travis CI machine, we want to set the backend via env variable
#      23     backend = os.environ.get("PMD_MPL_BACKEND", None)
# ---> 24     mpl = get_compatible_pyplot(backend=backend, debug=debug)
#      25
#      26 except ImportError:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pmdarima\compat\matplotlib.py in get_compatible_pyplot(backend, debug)
#      49                          % (existing_backend, os.linesep))
#      50
# ---> 51     from matplotlib import pyplot as plt
#      52     return plt
#      53
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in <module>
#      55 from matplotlib import docstring
#      56 from matplotlib.backend_bases import FigureCanvasBase, MouseButton
# ---> 57 from matplotlib.figure import Figure, figaspect
#      58 from matplotlib.gridspec import GridSpec, SubplotSpec
#      59 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\figure.py in <module>
#      23
#      24 import matplotlib as mpl
# ---> 25 from matplotlib import _blocking_input, docstring, projections
#      26 from matplotlib.artist import (
#      27     Artist, allow_rasterization, _finalize_rasterization)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\projections\__init__.py in <module>
#      53 """
#      54
# ---> 55 from .. import axes, docstring
#      56 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      57 from .polar import PolarAxes
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\__init__.py in <module>
# ----> 1 from ._subplots import *
#       2 from ._axes import *
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_subplots.py in <module>
#       1 import matplotlib as mpl
#       2 from matplotlib import _api, cbook
# ----> 3 from matplotlib.axes._axes import Axes
#       4 from matplotlib.gridspec import GridSpec, SubplotSpec
#       5
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py in <module>
#      45
#      46 @docstring.interpd
# ---> 47 class Axes(_AxesBase):
#      48     """
#      49     The `Axes` contains most of the figure elements: `~.axis.Axis`,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\docstring.py in __call__(self, obj)
#      84         super().__call__(obj)
#      85         if isinstance(obj, type) and obj.__init__ != object.__init__:
# ---> 86             self(obj.__init__)
#      87         return obj
#      88
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\docstring.py in __call__(self, obj)
#      82
#      83     def __call__(self, obj):
# ---> 84         super().__call__(obj)
#      85         if isinstance(obj, type) and obj.__init__ != object.__init__:
#      86             self(obj.__init__)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\docstring.py in __call__(self, func)
#      36     def __call__(self, func):
#      37         if func.__doc__:
# ---> 38             func.__doc__ = inspect.cleandoc(func.__doc__) % self.params
#      39         return func
#      40
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\docstring.py in __missing__(self, key)
#      62                     if cls.__name__ == name]
#      63         except ValueError as e:
# ---> 64             raise KeyError(key) from e
#      65         return self.setdefault(key, kwdoc(cls))
#      66
#
# KeyError: 'Axes:kwdoc'
